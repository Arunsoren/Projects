# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot, plot
import plotly.figure_factory as ff

# %% [markdown]
# 𝐒𝐮𝐛𝐩𝐥𝐨𝐭𝐬

# %%
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

# %%
#Vertcally stacking
fig, axs = plt.subplots(2)
plt.figure(figsize=(14,6))
fig.suptitle('Vertically stacked subplots')
axs[0].plot(x, y)
axs[1].plot(x, -y)

# %%
#Horizontal plot
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax2.plot(x, -y)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(7, 7),
                       gridspec_kw={
                           'width_ratios': [3, 3],
                           'height_ratios': [3, 3],
                       'wspace': 0.4,
                       'hspace': 0.4})
ax[0][0].plot(x, y)
ax[0][1].plot(x, y)
ax[1][0].plot(x, y)
ax[1][1].plot(x, y)
 
plt.show()

# %%
fig = plt.figure()
fig.set_figheight(6)
fig.set_figwidth(6)
 
ax1 = plt.subplot2grid(shape=(3, 3), loc=(0, 0), colspan=3)
ax2 = plt.subplot2grid(shape=(3, 3), loc=(1, 0), colspan=1)
ax3 = plt.subplot2grid(shape=(3, 3), loc=(1, 2), rowspan=2)
ax4 = plt.subplot2grid((3, 3), (2, 0))
ax5 = plt.subplot2grid((3, 3), (2, 1), colspan=1)

 
# plotting subplots
ax1.plot(x, y)
ax1.set_title('ax1')
ax2.plot(x, y)
ax2.set_title('ax2')
ax3.plot(x, y)
ax3.set_title('ax3')
ax4.plot(x, y)
ax4.set_title('ax4')
ax5.plot(x, y)
ax5.set_title('ax5')


plt.tight_layout()
plt.show()

# %%
spotify_df = pd.read_csv("spotify.csv", index_col="Date", parse_dates=True)
spotify_df.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %% [markdown]
# 𝗟𝗶𝗻𝗲𝗽𝗹𝗼𝘁:

# %%
plt.figure(figsize=(14,6))
plt.title("Daily Global Streams Popular Songs")
sns.lineplot(data = spotify_df)

# %% [markdown]
# 𝗧𝗿𝗲𝗻𝗱𝘀 -       A trend is defined as a pattern of change.
#
# sns.lineplot - Line charts are best to show trends over a period of time, and multiple lines can be used to show trends in more                than one group.

# %%
list(spotify_df.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
plt.figure(figsize=(14, 6))
plt.title("Daily, Global Stream of Popular Songs")
sns.lineplot(data=spotify_df["Shape of You"], label="Shape of You")
sns.lineplot(data=spotify_df["Despacito"], label= "Despacito")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# 𝗥𝗲𝗹𝗮𝘁𝗶𝗼𝗻𝘀𝗵𝗶𝗽:
#
# sns.barplot -     Bar charts are useful for comparing quantities corresponding to different groups.
# sns.heatmap -     Heatmaps can be used to find color-coded patterns in tables of numbers.
# sns.scatterplot - Scatter plots show the relationship between two continuous variables; if color-coded, we can also show the                     relationship with a third categorical variable.
# sns.regplot -     Including a regression line in the scatter plot makes it easier to see any linear relationship between two                     variables.
# sns.lmplot -      This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-                     coded groups.
# sns.swarmplot -   Categorical scatter plots show the relationship between a continuous variable and a categorical variable.

# %% [markdown]
# 𝗕𝗔𝗥𝗣𝗟𝗢𝗧:

# %%
ign_df = pd.read_csv("ign.csv", index_col="Platform")
ign_df.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# ...

# %%
plt.figure(figsize=(12, 6))
plt.title("Average Score of Racing ")
sns.barplot(x = ign_df["Racing"], y= ign_df.index)

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(ign_df, annot=True)
plt.xlabel("Genre")
plt.title("Average Game Score")
# Out:
# Text(0.5, 1.0, 'Average Game Score')

# %% [markdown]
# 𝗦𝗰𝗮𝘁𝘁𝗲𝗿𝗽𝗹𝗼𝘁

# %%
inc_df = pd.read_csv("insurance.csv")
inc_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(x= inc_df["bmi"], y = inc_df["charges"])

# %%
#with color coded
plt.figure(figsize=(14,6))
sns.scatterplot(x= inc_df["bmi"], y = inc_df["charges"], hue=inc_df["smoker"])

# %% [markdown]
# 𝗩𝗶𝗼𝗹𝗶𝗻𝗽𝗹𝗼𝘁

# %%
plt.figure(figsize=(14,6))
sns.set_theme(style="whitegrid")
sns.violinplot(x="bmi", y = "charges", hue="smoker", data=inc_df, palette="muted")

# %% [markdown]
# 𝗥𝗲𝗴𝗽𝗹𝗼𝘁

# %%
plt.figure(figsize=(14,6))
sns.regplot(x=inc_df["bmi"], y = inc_df["charges"])

# %% [markdown]
# 𝗥𝗲𝗴𝗿𝗲𝘀𝘀𝗶𝗼𝗻 𝗹𝗶𝗻𝗲

# %%
#regression line
sns.lmplot(x= "bmi", y="charges", hue="smoker",  data=inc_df, order= 2)

# %% [markdown]
# 𝗦𝘄𝗮𝗿𝗺𝗽𝗹𝗼𝘁

# %%
plt.figure(figsize=(15,7))
sns.swarmplot(x= "smoker",y = "charges", data= inc_df)
# Out:
# C:\Users\ARUN KUMAR SOREN\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧 - We visualize distributions to show the possible values that we can expect to see in a variable, along with how                   likely they are.
#
# sns.distplot - Histograms show the distribution of a single numerical variable.
# sns.kdeplot -  KDE plots (or 2D KDE plots) show an estimated, smooth distribution of a single numerical variable (or two                      numerical variables).
# sns.jointplot - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each                  individual variable.

# %%
iris_df = pd.read_csv("iris.csv", index_col="Id")
iris_df.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
iris_df.columns
# Out:
# Index(['Sepal Length (cm)', 'Sepal Width (cm)', 'Petal Length (cm)',
#        'Petal Width (cm)', 'Species'],
#       dtype='object')

# %%
#histogram
plt.figure(figsize=(14,6))
sns.distplot(a = iris_df["Petal Width (cm)"], kde= False)

# %%
#KDE plot
plt.figure(figsize=(14,6))
sns.kdeplot(data= iris_df["Petal Length (cm)"], shade= True)

# %%
#pairplot
sns.pairplot(iris_df,hue= "Species" ,  kind="kde")

# %%
#2D kde plot
plt.figure(figsize=(14, 6))
sns.jointplot(x=iris_df["Petal Length (cm)"], y=iris_df["Sepal Length (cm)"], kind="kde")

# %%
iris_set_data = pd.read_csv("iris_setosa.csv", index_col="Id")
iris_ver_data = pd.read_csv("iris_versicolor.csv", index_col="Id")
iris_vir_data = pd.read_csv("iris_virginica.csv", index_col="Id")

# %%
iris_ver_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 51                7.0               3.2                4.7               1.4
# 52                6.4               3.2                4.5               1.5
# 53                6.9               3.1                4.9               1.5
# 54                5.5               2.3                4.0               1.3
# 55                6.5               2.8                4.6               1.5
#
#             Species
# Id
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor

# %%
plt.figure(figsize=(14, 6))
sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", kde=False)
plt.title("Histogram ofr petal lengths, by species")
plt.legend()

# %% [markdown]
# 𝐃𝐢𝐬𝐭𝐫𝐢𝐛𝐮𝐭𝐢𝐨𝐧

# %%
cancer_b = pd.read_csv("cancer_b.csv", index_col= "Id")
cancer_m = pd.read_csv("cancer_m.csv", index_col= "Id")

# %%
cancer_b.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
cancer_m.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 842302           M          17.99           10.38            122.80
# 842517           M          20.57           17.77            132.90
# 84300903         M          19.69           21.25            130.00
# 84348301         M          11.42           20.38             77.58
# 84358402         M          20.29           14.34            135.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 842302         1001.0            0.11840             0.27760
# 842517         1326.0            0.08474             0.07864
# 84300903       1203.0            0.10960             0.15990
# 84348301        386.1            0.14250             0.28390
# 84358402       1297.0            0.10030             0.13280
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
plt.figure(figsize=(14, 6))
sns.distplot(a = cancer_b["Area (mean)"], label = "Area of B data", kde= False) 
sns.distplot(a = cancer_m["Area (mean)"], label = "Area of M data", kde= False) 
plt.legend()

# %%
plt.figure(figsize=(14, 6))
sns.kdeplot(data=cancer_b["Radius (worst)"], shade = True, label="Benign") 
sns.kdeplot(data=cancer_m["Radius (worst)"], shade = True, label="Malignant")
plt.legend()

# %%
#changing the style
sns.set_style("dark")     #darkgrid, whitegrid, dark, white, ticks
plt.figure(figsize=(14,6))
sns.lineplot(data= spotify_df)

# %%
#Scatter Matrix plot but hard to look at details.
